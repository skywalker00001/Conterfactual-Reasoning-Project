# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker00001/Conterfactual-Reasoning-Project/blob/main/time_travel2.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import and Install

# %%
from google.colab import drive
drive.mount('/content/drive')
root = 'drive/MyDrive/LM/'
# Out:
# Mounted at /content/drive

# %%
# !pip install simplet5
# Out:
# Collecting simplet5
#   Downloading simplet5-0.1.3.tar.gz (7.2 kB)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 4.2 MB/s
# Requirement already satisfied: torch!=1.8.0,>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from simplet5) (1.10.0+cu111)
# Collecting transformers==4.10.0
#   Downloading transformers-4.10.0-py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 63.4 MB/s
# Collecting pytorch-lightning==1.4.5
#   Downloading pytorch_lightning-1.4.5-py3-none-any.whl (919 kB)
#      |████████████████████████████████| 919 kB 72.3 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from simplet5) (4.62.3)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.4.5->simplet5) (1.19.5)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.4.5->simplet5) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.4.5->simplet5) (3.10.0.2)
# Collecting pyDeprecate==0.3.1
#   Downloading pyDeprecate-0.3.1-py3-none-any.whl (10 kB)
# Collecting PyYAML>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 78.4 MB/s
# Collecting torchmetrics>=0.4.0
#   Downloading torchmetrics-0.7.0-py3-none-any.whl (396 kB)
#      |████████████████████████████████| 396 kB 74.4 MB/s
# Collecting future>=0.17.1
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 75.8 MB/s
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.1.0-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 72.6 MB/s
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.4.5->simplet5) (2.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.0->simplet5) (3.4.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.0->simplet5) (2019.12.20)
# Collecting huggingface-hub>=0.0.12
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 6.6 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.0->simplet5) (4.10.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 67.0 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 52.1 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.0->simplet5) (2.23.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 64.6 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch-lightning==1.4.5->simplet5) (3.0.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (0.6.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (1.43.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (0.12.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (3.17.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (57.4.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (0.37.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (0.4.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.4->tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.10.0->simplet5) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.10.0->simplet5) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.10.0->simplet5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.10.0->simplet5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.10.0->simplet5) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.4.5->simplet5) (3.1.1)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 69.8 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.4.5->simplet5) (2.0.10)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (192 kB)
#      |████████████████████████████████| 192 kB 66.6 MB/s
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 77.5 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.4.5->simplet5) (21.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.10.0->simplet5) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.10.0->simplet5) (1.1.0)
# Building wheels for collected packages: simplet5, future
#   Building wheel for simplet5 (setup.py) ... done
#   Created wheel for simplet5: filename=simplet5-0.1.3-py3-none-any.whl size=6832 sha256=a4d8e5a60af97d4cce1d23d1c13f4075f5ee9c19a4bf8ea003b181840ebac7c5
#   Stored in directory: /root/.cache/pip/wheels/fb/87/9d/190f8091eed71a654458ca3a285743ed9ffeb55c2ffa4be68f
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=d6e55b2946e784f6fa126d150c340b055ec66004d0974022d0f0cd89f545d76c
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# Successfully built simplet5 future
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, PyYAML, pyDeprecate, fsspec, aiohttp, torchmetrics, tokenizers, sacremoses, huggingface-hub, future, transformers, sentencepiece, pytorch-lightning, simplet5
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.2.0 fsspec-2022.1.0 future-0.18.2 huggingface-hub-0.4.0 multidict-5.2.0 pyDeprecate-0.3.1 pytorch-lightning-1.4.5 sacremoses-0.0.47 sentencepiece-0.1.96 simplet5-0.1.3 tokenizers-0.10.3 torchmetrics-0.7.0 transformers-4.10.0 yarl-1.7.2

# %%
import transformers
transformers.models.auto.__spec__  = True
from simplet5 import SimpleT5
from tqdm import tqdm
import pandas as pd
from sklearn.model_selection import train_test_split

import os
import regex as re
# Out:
# Global seed set to 42

# %%
# Global Parameter
model_version = "2.1"

# %%
small_path = root + '/TimeTravel/train_supervised_small.json'
small_df = pd.read_json(small_path, lines=True)
small_df.head()
# Out:
#                                story_id  ...                                      edited_ending
# 0  080198fc-d0e7-42b3-8e63-b2144e59d816  ...  [I paid the cashier and patiently waited at th...
# 1  1ba02a18-8807-4f39-9271-ef555597ce21  ...  [He decided he would continue the business., H...
# 2  dbb0ad3e-9389-44ee-8290-7c3458e3fa0f  ...  [Instead of going home they went to the shark ...
# 3  e5955040-5b87-4acb-a8c7-7e81d0ffb9f5  ...  [Suddenly, an earthquake sent her falling back...
# 4  dc234072-2e69-4999-9e2f-632d3ea30b78  ...  [She didn't have enough time to brake and drov...
#
# [5 rows x 6 columns]

# %%
print(small_df.loc[:,"edited_ending"][0])
# Out:
# ['I paid the cashier and patiently waited at the counter for my drink.', 'When she handed me the drink, the lid came off and spilled on me.', 'The coffee hurt and I had to go home and change clothes.']

# %%
text_a, text_b = [], []

for i in range(len(small_df)):
  text_a.append("premise: " + small_df.loc[i, 'premise'] + " initial: " + \
                small_df.loc[i, 'initial'] + " counterfactual: " + small_df.loc[i, 'counterfactual'] + \
                " original_ending: " + small_df.loc[i, 'original_ending'])
  #text_a.append(re.sub(re_pat, df.loc[i, 'edit1'], df.loc[i, 'original1']))
  text_b.append("edited_ending: " + small_df.loc[i, 'edited_ending'][0] +" "+ small_df.loc[i, 'edited_ending'][1] +" "+ \
                small_df.loc[i, 'edited_ending'][2])

# %%
processed_df = pd.DataFrame({'source_text': text_a, 'target_text': text_b}) 
processed_df.head()
# Out:
#                                          source_text                                        target_text
# 0  premise: On my way to work I stopped to get so...  edited_ending: I paid the cashier and patientl...
# 1  premise: Terry aspired to be a chef. initial: ...  edited_ending: He decided he would continue th...
# 2  premise: Kim and her glass went on a field tri...  edited_ending: Instead of going home they went...
# 3  premise: Susie was sitting on her barstool. in...  edited_ending: Suddenly, an earthquake sent he...
# 4  premise: Celeste rode her motorcycle across th...  edited_ending: She didn't have enough time to ...

# %%
print(processed_df.loc[0, "source_text"])
print("-------------")
print(processed_df.loc[0, "target_text"])
# Out:
# premise: On my way to work I stopped to get some coffee. initial: I went through the drive through and placed my order. counterfactual: I went inside to place my order. original_ending: I paid the cashier and patiently waited for my drink. When she handed me the drink, the lid came off and spilled on me. The coffee hurt and I had to go home and change clothes.
# -------------
# edited_ending: I paid the cashier and patiently waited at the counter for my drink. When she handed me the drink, the lid came off and spilled on me.The coffee hurt and I had to go home and change clothes.

# %%
print(processed_df.shape)
# Out:
# (16752, 2)

# %%
train_df, test_df = train_test_split(processed_df, test_size=0.2)
train_df.shape, test_df.shape
# Out:
# ((13401, 2), (3351, 2))

# %% [markdown]
# # Train using T5

# %%
model = SimpleT5()
model.from_pretrained(model_type="t5", model_name="t5-base")
model.train(train_df=train_df,
            eval_df=test_df, 
            source_max_token_len=128, 
            target_max_token_len=128, 
            batch_size=16, max_epochs=80, use_gpu=True)
# Out:
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/892M [00:00<?, ?B/s]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type                       | Params
# -----------------------------------------------------
# 0 | model | T5ForConditionalGeneration | 222 M
# -----------------------------------------------------
# 222 M     Trainable params
# 0         Non-trainable params
# 222 M     Total params
# 891.614   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Global seed set to 42
# Training: -1it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]

# %%
# !ls ./outputs
# Out:
# simplet5-epoch-0-train-loss-0.9078   simplet5-epoch-46-train-loss-0.0384
# simplet5-epoch-10-train-loss-0.3921  simplet5-epoch-47-train-loss-0.0379
# simplet5-epoch-11-train-loss-0.3631  simplet5-epoch-48-train-loss-0.0353
# simplet5-epoch-12-train-loss-0.3374  simplet5-epoch-49-train-loss-0.0337
# simplet5-epoch-13-train-loss-0.3112  simplet5-epoch-4-train-loss-0.6258
# simplet5-epoch-14-train-loss-0.2895  simplet5-epoch-50-train-loss-0.0339
# simplet5-epoch-15-train-loss-0.2663  simplet5-epoch-51-train-loss-0.0334
# simplet5-epoch-16-train-loss-0.247   simplet5-epoch-52-train-loss-0.0312
# simplet5-epoch-17-train-loss-0.231   simplet5-epoch-53-train-loss-0.0307
# simplet5-epoch-18-train-loss-0.2132  simplet5-epoch-54-train-loss-0.0301
# simplet5-epoch-19-train-loss-0.197   simplet5-epoch-55-train-loss-0.0289
# simplet5-epoch-1-train-loss-0.794    simplet5-epoch-56-train-loss-0.028
# simplet5-epoch-20-train-loss-0.1816  simplet5-epoch-57-train-loss-0.0274
# simplet5-epoch-21-train-loss-0.1685  simplet5-epoch-58-train-loss-0.027
# simplet5-epoch-22-train-loss-0.1569  simplet5-epoch-59-train-loss-0.0259
# simplet5-epoch-23-train-loss-0.1437  simplet5-epoch-5-train-loss-0.5778
# simplet5-epoch-24-train-loss-0.1337  simplet5-epoch-60-train-loss-0.0258
# simplet5-epoch-25-train-loss-0.125   simplet5-epoch-61-train-loss-0.0249
# simplet5-epoch-26-train-loss-0.1155  simplet5-epoch-62-train-loss-0.0241
# simplet5-epoch-27-train-loss-0.1068  simplet5-epoch-63-train-loss-0.0234
# simplet5-epoch-28-train-loss-0.0999  simplet5-epoch-64-train-loss-0.0232
# simplet5-epoch-29-train-loss-0.0921  simplet5-epoch-65-train-loss-0.0227
# simplet5-epoch-2-train-loss-0.7342   simplet5-epoch-66-train-loss-0.0218
# simplet5-epoch-30-train-loss-0.0868  simplet5-epoch-67-train-loss-0.0214
# simplet5-epoch-31-train-loss-0.0809  simplet5-epoch-68-train-loss-0.0211
# simplet5-epoch-32-train-loss-0.0757  simplet5-epoch-69-train-loss-0.0205
# simplet5-epoch-33-train-loss-0.0715  simplet5-epoch-6-train-loss-0.5324
# simplet5-epoch-34-train-loss-0.0665  simplet5-epoch-70-train-loss-0.0207
# simplet5-epoch-35-train-loss-0.0641  simplet5-epoch-71-train-loss-0.0202
# simplet5-epoch-36-train-loss-0.0594  simplet5-epoch-72-train-loss-0.0198
# simplet5-epoch-37-train-loss-0.0565  simplet5-epoch-73-train-loss-0.0196
# simplet5-epoch-38-train-loss-0.0538  simplet5-epoch-74-train-loss-0.0185
# simplet5-epoch-39-train-loss-0.0514  simplet5-epoch-75-train-loss-0.0191
# simplet5-epoch-3-train-loss-0.6788   simplet5-epoch-76-train-loss-0.0181
# simplet5-epoch-40-train-loss-0.0477  simplet5-epoch-77-train-loss-0.0191
# simplet5-epoch-41-train-loss-0.0465  simplet5-epoch-78-train-loss-0.0175
# simplet5-epoch-42-train-loss-0.0446  simplet5-epoch-79-train-loss-0.0178
# simplet5-epoch-43-train-loss-0.0426  simplet5-epoch-7-train-loss-0.4938
# simplet5-epoch-44-train-loss-0.0415  simplet5-epoch-8-train-loss-0.4575
# simplet5-epoch-45-train-loss-0.0392  simplet5-epoch-9-train-loss-0.4237

# %%
models_dir = "./outputs/"
ckpt_files = os.listdir(models_dir)
print('All files are:')
print(f'\t{ckpt_files}')
print(len(ckpt_files))

loss_epoch = re.compile(r'loss-\d+\.\d+') # 正则表达式，匹配-val后面的数字，代表第几个epoch
ckpt_files_sorted = sorted(ckpt_files, key=lambda t: re.findall(loss_epoch, t)[0], reverse=False) # 按照valxxx的xxx进行倒叙排序，因为最新的epoch才保存最好的model
print('Sorting .ckpt files:')
print(f'\t{ckpt_files_sorted}')
print()

print('Best model file is:')
best_model_name = ckpt_files_sorted[0]
print(f'\t{best_model_name}')
# Out:
# All files are:
# 	['simplet5-epoch-45-train-loss-0.0392', 'simplet5-epoch-57-train-loss-0.0274', 'simplet5-epoch-5-train-loss-0.5778', 'simplet5-epoch-50-train-loss-0.0339', 'simplet5-epoch-10-train-loss-0.3921', 'simplet5-epoch-77-train-loss-0.0191', 'simplet5-epoch-75-train-loss-0.0191', 'simplet5-epoch-67-train-loss-0.0214', 'simplet5-epoch-9-train-loss-0.4237', 'simplet5-epoch-59-train-loss-0.0259', 'simplet5-epoch-35-train-loss-0.0641', 'simplet5-epoch-69-train-loss-0.0205', 'simplet5-epoch-7-train-loss-0.4938', 'simplet5-epoch-2-train-loss-0.7342', 'simplet5-epoch-42-train-loss-0.0446', 'simplet5-epoch-30-train-loss-0.0868', 'simplet5-epoch-21-train-loss-0.1685', 'simplet5-epoch-33-train-loss-0.0715', 'simplet5-epoch-26-train-loss-0.1155', 'simplet5-epoch-70-train-loss-0.0207', 'simplet5-epoch-43-train-loss-0.0426', 'simplet5-epoch-1-train-loss-0.794', 'simplet5-epoch-28-train-loss-0.0999', 'simplet5-epoch-24-train-loss-0.1337', 'simplet5-epoch-36-train-loss-0.0594', 'simplet5-epoch-72-train-loss-0.0198', 'simplet5-epoch-62-train-loss-0.0241', 'simplet5-epoch-13-train-loss-0.3112', 'simplet5-epoch-16-train-loss-0.247', 'simplet5-epoch-66-train-loss-0.0218', 'simplet5-epoch-44-train-loss-0.0415', 'simplet5-epoch-61-train-loss-0.0249', 'simplet5-epoch-11-train-loss-0.3631', 'simplet5-epoch-6-train-loss-0.5324', 'simplet5-epoch-71-train-loss-0.0202', 'simplet5-epoch-25-train-loss-0.125', 'simplet5-epoch-64-train-loss-0.0232', 'simplet5-epoch-51-train-loss-0.0334', 'simplet5-epoch-23-train-loss-0.1437', 'simplet5-epoch-34-train-loss-0.0665', 'simplet5-epoch-41-train-loss-0.0465', 'simplet5-epoch-46-train-loss-0.0384', 'simplet5-epoch-0-train-loss-0.9078', 'simplet5-epoch-22-train-loss-0.1569', 'simplet5-epoch-17-train-loss-0.231', 'simplet5-epoch-40-train-loss-0.0477', 'simplet5-epoch-65-train-loss-0.0227', 'simplet5-epoch-79-train-loss-0.0178', 'simplet5-epoch-27-train-loss-0.1068', 'simplet5-epoch-55-train-loss-0.0289', 'simplet5-epoch-78-train-loss-0.0175', 'simplet5-epoch-74-train-loss-0.0185', 'simplet5-epoch-14-train-loss-0.2895', 'simplet5-epoch-68-train-loss-0.0211', 'simplet5-epoch-29-train-loss-0.0921', 'simplet5-epoch-49-train-loss-0.0337', 'simplet5-epoch-8-train-loss-0.4575', 'simplet5-epoch-60-train-loss-0.0258', 'simplet5-epoch-48-train-loss-0.0353', 'simplet5-epoch-56-train-loss-0.028', 'simplet5-epoch-58-train-loss-0.027', 'simplet5-epoch-37-train-loss-0.0565', 'simplet5-epoch-15-train-loss-0.2663', 'simplet5-epoch-19-train-loss-0.197', 'simplet5-epoch-52-train-loss-0.0312', 'simplet5-epoch-3-train-loss-0.6788', 'simplet5-epoch-47-train-loss-0.0379', 'simplet5-epoch-54-train-loss-0.0301', 'simplet5-epoch-12-train-loss-0.3374', 'simplet5-epoch-38-train-loss-0.0538', 'simplet5-epoch-20-train-loss-0.1816', 'simplet5-epoch-63-train-loss-0.0234', 'simplet5-epoch-18-train-loss-0.2132', 'simplet5-epoch-73-train-loss-0.0196', 'simplet5-epoch-32-train-loss-0.0757', 'simplet5-epoch-53-train-loss-0.0307', 'simplet5-epoch-4-train-loss-0.6258', 'simplet5-epoch-39-train-loss-0.0514', 'simplet5-epoch-76-train-loss-0.0181', 'simplet5-epoch-31-train-loss-0.0809']
# 80
# Sorting .ckpt files:
# 	['simplet5-epoch-78-train-loss-0.0175', 'simplet5-epoch-79-train-loss-0.0178', 'simplet5-epoch-76-train-loss-0.0181', 'simplet5-epoch-74-train-loss-0.0185', 'simplet5-epoch-77-train-loss-0.0191', 'simplet5-epoch-75-train-loss-0.0191', 'simplet5-epoch-73-train-loss-0.0196', 'simplet5-epoch-72-train-loss-0.0198', 'simplet5-epoch-71-train-loss-0.0202', 'simplet5-epoch-69-train-loss-0.0205', 'simplet5-epoch-70-train-loss-0.0207', 'simplet5-epoch-68-train-loss-0.0211', 'simplet5-epoch-67-train-loss-0.0214', 'simplet5-epoch-66-train-loss-0.0218', 'simplet5-epoch-65-train-loss-0.0227', 'simplet5-epoch-64-train-loss-0.0232', 'simplet5-epoch-63-train-loss-0.0234', 'simplet5-epoch-62-train-loss-0.0241', 'simplet5-epoch-61-train-loss-0.0249', 'simplet5-epoch-60-train-loss-0.0258', 'simplet5-epoch-59-train-loss-0.0259', 'simplet5-epoch-58-train-loss-0.027', 'simplet5-epoch-57-train-loss-0.0274', 'simplet5-epoch-56-train-loss-0.028', 'simplet5-epoch-55-train-loss-0.0289', 'simplet5-epoch-54-train-loss-0.0301', 'simplet5-epoch-53-train-loss-0.0307', 'simplet5-epoch-52-train-loss-0.0312', 'simplet5-epoch-51-train-loss-0.0334', 'simplet5-epoch-49-train-loss-0.0337', 'simplet5-epoch-50-train-loss-0.0339', 'simplet5-epoch-48-train-loss-0.0353', 'simplet5-epoch-47-train-loss-0.0379', 'simplet5-epoch-46-train-loss-0.0384', 'simplet5-epoch-45-train-loss-0.0392', 'simplet5-epoch-44-train-loss-0.0415', 'simplet5-epoch-43-train-loss-0.0426', 'simplet5-epoch-42-train-loss-0.0446', 'simplet5-epoch-41-train-loss-0.0465', 'simplet5-epoch-40-train-loss-0.0477', 'simplet5-epoch-39-train-loss-0.0514', 'simplet5-epoch-38-train-loss-0.0538', 'simplet5-epoch-37-train-loss-0.0565', 'simplet5-epoch-36-train-loss-0.0594', 'simplet5-epoch-35-train-loss-0.0641', 'simplet5-epoch-34-train-loss-0.0665', 'simplet5-epoch-33-train-loss-0.0715', 'simplet5-epoch-32-train-loss-0.0757', 'simplet5-epoch-31-train-loss-0.0809', 'simplet5-epoch-30-train-loss-0.0868', 'simplet5-epoch-29-train-loss-0.0921', 'simplet5-epoch-28-train-loss-0.0999', 'simplet5-epoch-27-train-loss-0.1068', 'simplet5-epoch-26-train-loss-0.1155', 'simplet5-epoch-25-train-loss-0.125', 'simplet5-epoch-24-train-loss-0.1337', 'simplet5-epoch-23-train-loss-0.1437', 'simplet5-epoch-22-train-loss-0.1569', 'simplet5-epoch-21-train-loss-0.1685', 'simplet5-epoch-20-train-loss-0.1816', 'simplet5-epoch-19-train-loss-0.197', 'simplet5-epoch-18-train-loss-0.2132', 'simplet5-epoch-17-train-loss-0.231', 'simplet5-epoch-16-train-loss-0.247', 'simplet5-epoch-15-train-loss-0.2663', 'simplet5-epoch-14-train-loss-0.2895', 'simplet5-epoch-13-train-loss-0.3112', 'simplet5-epoch-12-train-loss-0.3374', 'simplet5-epoch-11-train-loss-0.3631', 'simplet5-epoch-10-train-loss-0.3921', 'simplet5-epoch-9-train-loss-0.4237', 'simplet5-epoch-8-train-loss-0.4575', 'simplet5-epoch-7-train-loss-0.4938', 'simplet5-epoch-6-train-loss-0.5324', 'simplet5-epoch-5-train-loss-0.5778', 'simplet5-epoch-4-train-loss-0.6258', 'simplet5-epoch-3-train-loss-0.6788', 'simplet5-epoch-2-train-loss-0.7342', 'simplet5-epoch-1-train-loss-0.794', 'simplet5-epoch-0-train-loss-0.9078']
#
# Best model file is:
# 	simplet5-epoch-78-train-loss-0.0175

# %%
best_model_name
# Out:
# 'simplet5-epoch-78-train-loss-0.0175'

# %%
# let's load the trained model for inferencing:
model.load_model("t5","outputs/" + best_model_name, use_gpu=True)

# %% [markdown]
# # Save the model

# %%
import shutil 

def copy_allfiles(src,dest):
#src:原文件夹；dest:目标文件夹
  src_files = os.listdir(src)
  for file_name in src_files:
    full_file_name = os.path.join(src, file_name)
    if os.path.isfile(full_file_name):
        shutil.copy(full_file_name, dest)

# %%
model_iter = "model2.1"
copy_allfiles("outputs/" + best_model_name, root + "models/model" + model_version)

# %%
# model.load_model("t5",root+'models/model2.1', use_gpu=True)

# %% [markdown]
# # Inference

# %%
large_path = root + '/TimeTravel/train_supervised_large.json'
df_large = pd.read_json(large_path, lines=True)
print(len(df_large))
# Out:
# 28363

# %%
small_ids = []
for i in range(len(small_df)):
    small_ids.append(small_df.loc[i, 'story_id'])

print(len(small_ids))
# Out:
# 16752

# %%
df_large = df_large[~df_large.story_id.isin(small_ids)]
df_large = df_large.reset_index()   # must reset index after delete rows
print(len(df_large))
# Out:
# 11613

# %%
# select data not in training set
part_df_large = df_large[0:1000]
df_large = df_large.reset_index()
print(len(part_df_large))
# Out:
# 1000

# %%
part_df_large.head(10)
# Out:
#    index  ...                                      edited_ending
# 0   4183  ...  [Soon,everyone wanted to spend time with her.,...
# 1   4184  ...  [Bill congratulated the other team., He also w...
# 2   4185  ...  [She jumped over the fence and vanished., With...
# 3   4186  ...  [She was nervous about helping the people and ...
# 4   4187  ...  [I tried to stay quiet and busy., I knew I cou...
# 5   4188  ...  [Jeff then became distant and wasn't the same ...
# 6   4189  ...  [Then the salesman took my measurements., Afte...
# 7   4190  ...  [He decides to pull over and see what's wrong....
# 8   4191  ...  [It landed on a pedestrian's foot., The pedest...
# 9   4192  ...  [She felt obliged, but she chose not to go., A...
#
# [10 rows x 7 columns]

# %%
text, gt = [],[] # gt for ground truth

for i in range(len(part_df_large)):
  text.append("premise: " + part_df_large.loc[i, 'premise'] + \
              " initial: " + part_df_large.loc[i, 'initial'] + \
              " counterfactual: " + part_df_large.loc[i, 'counterfactual'] + \
              " original_ending: " + part_df_large.loc[i, 'original_ending'])
  gt.append("edited_ending: " + part_df_large.loc[i, 'edited_ending'][0] +" "+ \
            part_df_large.loc[i, 'edited_ending'][1] +" "+ part_df_large.loc[i, 'edited_ending'][2])

print(len(text))
# Out:
# 1000

# %%
# %time
#origin = []
edit_endings = []
for i in tqdm(range(len(text))):
    #origin.append(processed_un_df.loc[i, 'raw_text'])
    edit_endings.extend(model.predict(text[i]))
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 8.11 µs
# 100%|██████████| 1000/1000 [09:45<00:00,  1.71it/s]

# %%
out_df = pd.DataFrame({'raw_text': text, 'ground_truth': gt, 'generated_text': edit_endings})

# %%
out_df.to_csv(root + 'results/' + 'output' + model_version + '.csv')
out_df.to_json(root + 'results/' + 'output' + model_version + '.json')

# %%
import difflib

#判断相似度的方法，用到了difflib库
def get_equal_rate_1(str1, str2):
   return difflib.SequenceMatcher(None, str1, str2).quick_ratio()

# %% [markdown]
# # Select some samples

# %%
print(small_df[small_df.story_id == "0930f02c-df49-480c-be22-91db02976e01"])
# Out:
#                                   story_id  ...                                      edited_ending
# 1336  0930f02c-df49-480c-be22-91db02976e01  ...  [I was so happy to see her., I breathed a sigh...
#
# [1 rows x 6 columns]

# %%
samp = small_df[small_df.story_id == "0930f02c-df49-480c-be22-91db02976e01"]
sample1 = "premise: " + samp.premise.item() + \
              " initial: " + samp.initial.item() + \
              " counterfactual: " + samp.counterfactual.item() + \
              " original_ending: " + samp.original_ending.item()
print(sample1)
# Out:
# premise: I screamed as I woke up! initial: The pretty girl I'd ogled this morning was attacking me with a knife! counterfactual: The pretty girl I married was offering me a cupcake. original_ending: I was so freaked out, I ran to my kitchen and opened the freezer. I breathed a sigh of absolute relief. She was still there, where I'd left her.

# %%
model.predict(sample1)
# Out:
# ['edited_ending: I was so happy to see her. I breathed a sigh of absolute content.She was still there in bed next to me.']
